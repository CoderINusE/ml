# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('bikes_rent.csv', header = 0, sep = ',')
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed(mph)  windspeed(ms)   cnt
# 0  18.18125  80.5833       10.749882       4.805490   985
# 1  17.68695  69.6087       16.652113       7.443949   801
# 2   9.47025  43.7273       16.636703       7.437060  1349
# 3  10.60610  59.0435       10.739832       4.800998  1562
# 4  11.46350  43.6957       12.522300       5.597810  1600

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
for idx, feature in enumerate(df.columns[:-1]):
    df.plot(feature, "cnt", subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])

# %%
corrw = df.loc[:,df.columns[:-1]].corrwith(df.loc[:,'cnt'])
corr = df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].corr(method='pearson')
corr
# Out:
#                     temp     atemp       hum  windspeed(mph)  windspeed(ms)  \
# temp            1.000000  0.991702  0.126963       -0.157944      -0.157944
# atemp           0.991702  1.000000  0.139988       -0.183643      -0.183643
# hum             0.126963  0.139988  1.000000       -0.248489      -0.248489
# windspeed(mph) -0.157944 -0.183643 -0.248489        1.000000       1.000000
# windspeed(ms)  -0.157944 -0.183643 -0.248489        1.000000       1.000000
# cnt             0.627494  0.631066 -0.100659       -0.234545      -0.234545
#
#                      cnt
# temp            0.627494
# atemp           0.631066
# hum            -0.100659
# windspeed(mph) -0.234545
# windspeed(ms)  -0.234545
# cnt             1.000000

# %%
df.mean()
# Out:
# season               2.496580
# yr                   0.500684
# mnth                 6.519836
# holiday              0.028728
# weekday              2.997264
# workingday           0.683995
# weathersit           1.395349
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle

# %%
df_shuffled = shuffle(df, random_state=1)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

# %% [markdown]
# Давайте обучим линейную регрессию на наших данных и посмотрим на веса признаков.

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X, y)
[print(x, ": ", y) for x, y in zip(df.columns, regr.coef_)]
# Out:
# season :  570.869441238
# yr :  1021.96744721
# mnth :  -141.30524923
# holiday :  -86.7599633437
# weekday :  137.226261157
# workingday :  56.3946412646
# weathersit :  -330.228329803
# temp :  367.463772694
# atemp :  585.567180625
# hum :  -145.61118932
# windspeed(mph) :  1.24597615228e+13
# windspeed(ms) :  -1.2459761523e+13
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
from sklearn.linear_model import Lasso, Ridge
regr_lasso = Lasso()
regr_lasso.fit(X, y)
[print(x, ": ", y) for x, y in zip(df.columns, regr_lasso.coef_)]
# Out:
# season :  298.828446632
# yr :  846.577230157
# mnth :  0.0
# holiday :  -0.0
# weekday :  0.0
# workingday :  0.0
# weathersit :  -236.452255923
# temp :  125.868203386
# atemp :  724.145012248
# hum :  -0.0
# windspeed(mph) :  -13.3959915428
# windspeed(ms) :  -2.78615229031e-08
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
regr_lasso = Ridge()
regr_lasso.fit(X, y)
print(list(zip(df.columns, regr_lasso.coef_)))
# Out:
# [('season', 563.06457225201427), ('yr', 1018.9483787875284), ('mnth', -131.87332028247403), ('holiday', -86.74609799709242), ('weekday', 138.00511117871898), ('workingday', 55.903110375064593), ('weathersit', -332.34978849907338), ('temp', 386.45788919195593), ('atemp', 566.34704706001958), ('hum', -145.07132729867206), ('windspeed(mph)', -99.259441081845949), ('windspeed(ms)', -99.25944115428787)]

# %%
alphas = np.arange(1, 2000, 5)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) # матрица весов размера (число регрессоров) x (число признаков)
coefs_ridge = np.zeros((alphas.shape[0], X.shape[1]))

for i in range(0, len(alphas)):
    coefs_lasso[i:i+1] = Lasso(alphas[i]).fit(X, y).coef_    
for i in range(0, len(alphas)):
    coefs_ridge[i:i+1] = Ridge(alphas[i]).fit(X, y).coef_

#print("Coefficient matrix for Lasso\n")    
#print(coefs_lasso)
#print("\nCoefficient matrix for Ridge\n")
#print(coefs_ridge)

plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_lasso.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_ridge.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")

# %%
from sklearn.linear_model import LassoCV

# %%
# taking mean of each alpha result by cross validation results
alphas = np.arange(1, 1000, 100)
lasso_regr = LassoCV(alphas=alphas)
lasso_regr.fit(X, y)
plt.plot(alphas, lasso_regr.mse_path_.mean(axis=1))
plt.xlabel("alpha")
plt.ylabel("mean cv")
plt.show()

# %%
# Код 3.3 (1 балл)
# Выведите значения alpha, соответствующие минимумам MSE на каждом разбиении (то есть по столбцам).
# На трех отдельных графиках визуализируйте столбцы .mse_path_

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
df.plot(alphas, lasso_regr.mse_path_, ax=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-7c39c16f7827> in <module>()
#       4
#       5 fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
# ----> 6 df.plot(alphas, lasso_regr.mse_path_, ax=0)
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1855                  yerr=yerr, xerr=xerr,
#    1856                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1857                  **kwds)
#    1858
#    1859
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1660                 if is_integer(x) and not data.columns.holds_integer():
#    1661                     x = data.columns[x]
# -> 1662                 data = data.set_index(x)
#    1663
#    1664             if y is not None:
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2944         index._cleanup()
#    2945
# -> 2946         frame.index = index
#    2947
#    2948         if not inplace:
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    2981         try:
#    2982             object.__getattribute__(self, name)
# -> 2983             return object.__setattr__(self, name, value)
#    2984         except AttributeError:
#    2985             pass
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas/_libs/lib.c:45103)()
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     469
#     470     def _set_axis(self, axis, labels):
# --> 471         self._data.set_axis(axis, labels)
#     472         self._clear_item_cache()
#     473
#
# /home/rasul/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    2834             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2835                              'new values have %d elements' %
# -> 2836                              (old_len, new_len))
#    2837
#    2838         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 731 elements, new values have 10 elements
